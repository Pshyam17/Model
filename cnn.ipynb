# %%
# os reads file and directory structure
# numpy for matrix math outside tf
# matplotlib.pyplot to plot graph and display images


import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
import os
import numpy as np
import matplotlib.pyplot as plt

# commandline interface
import argparse

# %%
pip install keras_preprocessing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from keras_preprocessing) (1.16.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from keras_preprocessing) (1.24.2)
# Installing collected packages: keras_preprocessing
# Successfully installed keras_preprocessing-1.1.2

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.DEBUG)

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount = True)
# Out:
# Mounted at /gdrive

# %%
data = '/gdrive/MyDrive/Colab Notebooks/data'

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(150, 150),
  batch_size=32)
# Out:
# Found 801 files belonging to 2 classes.
# Using 641 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(150, 150),
  batch_size=32)
# Out:
# Found 801 files belonging to 2 classes.
# Using 160 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['benign', 'malicious']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(2):
    ax = plt.subplot(1, 2, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)

# %%
Model = tf.keras.models.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(150, 150, 3)),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2)
])

# %%
Model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=32
history = Model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/32
# 21/21 [==============================] - 362s 6s/step - loss: 0.4908 - accuracy: 0.7332 - val_loss: 0.4212 - val_accuracy: 0.7437
# Epoch 2/32
# 21/21 [==============================] - 42s 2s/step - loss: 0.3279 - accuracy: 0.8612 - val_loss: 0.3495 - val_accuracy: 0.8750
# Epoch 3/32
# 21/21 [==============================] - 51s 2s/step - loss: 0.2909 - accuracy: 0.8705 - val_loss: 0.2796 - val_accuracy: 0.8938
# Epoch 4/32
# 21/21 [==============================] - 45s 2s/step - loss: 0.2435 - accuracy: 0.8924 - val_loss: 0.2269 - val_accuracy: 0.9062
# Epoch 5/32
# 21/21 [==============================] - 42s 2s/step - loss: 0.2942 - accuracy: 0.8658 - val_loss: 0.2697 - val_accuracy: 0.8875
# Epoch 6/32
# 21/21 [==============================] - 44s 2s/step - loss: 0.2764 - accuracy: 0.8939 - val_loss: 0.2659 - val_accuracy: 0.8875
# Epoch 7/32
# 21/21 [==============================] - 42s 2s/step - loss: 0.2777 - accuracy: 0.8596 - val_loss: 0.2328 - val_accuracy: 0.9000
# Epoch 8/32
# 21/21 [==============================] - 41s 2s/step - loss: 0.2181 - accuracy: 0.9017 - val_loss: 0.1917 - val_accuracy: 0.9250
# Epoch 9/32
# 21/21 [==============================] - 44s 2s/step - loss: 0.1801 - accuracy: 0.9314 - val_loss: 0.2105 - val_accuracy: 0.8750
# Epoch 10/32
# 21/21 [==============================] - 40s 2s/step - loss: 0.1566 - accuracy: 0.9204 - val_loss: 0.1764 - val_accuracy: 0.9375
# Epoch 11/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.1389 - accuracy: 0.9423 - val_loss: 0.1647 - val_accuracy: 0.9125
# Epoch 12/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.1410 - accuracy: 0.9360 - val_loss: 0.1399 - val_accuracy: 0.9438
# Epoch 13/32
# 21/21 [==============================] - 41s 2s/step - loss: 0.1117 - accuracy: 0.9501 - val_loss: 0.1267 - val_accuracy: 0.9563
# Epoch 14/32
# 21/21 [==============================] - 49s 2s/step - loss: 0.1016 - accuracy: 0.9563 - val_loss: 0.1118 - val_accuracy: 0.9625
# Epoch 15/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.0759 - accuracy: 0.9719 - val_loss: 0.1636 - val_accuracy: 0.9312
# Epoch 16/32
# 21/21 [==============================] - 41s 2s/step - loss: 0.0848 - accuracy: 0.9704 - val_loss: 0.2569 - val_accuracy: 0.9125
# Epoch 17/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.1155 - accuracy: 0.9579 - val_loss: 0.1169 - val_accuracy: 0.9563
# Epoch 18/32
# 21/21 [==============================] - 44s 2s/step - loss: 0.0799 - accuracy: 0.9704 - val_loss: 0.1296 - val_accuracy: 0.9375
# Epoch 19/32
# 21/21 [==============================] - 42s 2s/step - loss: 0.0585 - accuracy: 0.9735 - val_loss: 0.0947 - val_accuracy: 0.9625
# Epoch 20/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.0544 - accuracy: 0.9782 - val_loss: 0.1107 - val_accuracy: 0.9563
# Epoch 21/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.0600 - accuracy: 0.9766 - val_loss: 0.1520 - val_accuracy: 0.9438
# Epoch 22/32
# 21/21 [==============================] - 41s 2s/step - loss: 0.0772 - accuracy: 0.9704 - val_loss: 0.0859 - val_accuracy: 0.9688
# Epoch 23/32
# 21/21 [==============================] - 49s 2s/step - loss: 0.0464 - accuracy: 0.9797 - val_loss: 0.0661 - val_accuracy: 0.9812
# Epoch 24/32
# 21/21 [==============================] - 41s 2s/step - loss: 0.0435 - accuracy: 0.9844 - val_loss: 0.0446 - val_accuracy: 0.9937
# Epoch 25/32
# 21/21 [==============================] - 44s 2s/step - loss: 0.0406 - accuracy: 0.9813 - val_loss: 0.0651 - val_accuracy: 0.9750
# Epoch 26/32
# 21/21 [==============================] - 45s 2s/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.0541 - val_accuracy: 0.9812
# Epoch 27/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.0117 - accuracy: 0.9953 - val_loss: 0.0327 - val_accuracy: 0.9937
# Epoch 28/32
# 21/21 [==============================] - 42s 2s/step - loss: 0.0126 - accuracy: 0.9938 - val_loss: 0.0302 - val_accuracy: 0.9937
# Epoch 29/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.0127 - accuracy: 0.9969 - val_loss: 0.0329 - val_accuracy: 0.9937
# Epoch 30/32
# 21/21 [==============================] - 43s 2s/step - loss: 0.0200 - accuracy: 0.9969 - val_loss: 0.0454 - val_accuracy: 0.9750
# Epoch 31/32
# 21/21 [==============================] - 42s 2s/step - loss: 0.1097 - accuracy: 0.9719 - val_loss: 0.1015 - val_accuracy: 0.9563
# Epoch 32/32
# 21/21 [==============================] - 50s 2s/step - loss: 0.0687 - accuracy: 0.9735 - val_loss: 0.0781 - val_accuracy: 0.9625

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
trial_path = '/gdrive/MyDrive/CAT.jpeg'
img = tf.keras.utils.load_img(
    trial_path, target_size=(150, 150)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = Model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 75ms/step
# This image most likely belongs to benign with a 96.67 percent confidence.
